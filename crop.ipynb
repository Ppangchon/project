# %% [markdown]
# <a href="https://colab.research.google.com/github/Ppangchon/project/blob/main/crop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
import cv2
import matplotlib.pyplot as plt
import pathlib

# %%
from google.colab import drive # เชื่อม drive ของเรา ถ้าเชื่อมสำเร็จจะขึ้นคำว่าMounted at /content/drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # os จัดการเกี่ยวกับไฟล์ต่างๆ ในโฟล์เดอร์

# %%
path = '/content/drive/My Drive/Projecteye'  # ชี้ว่า data เราอยู่โฟล์เดอร์ไหน

# %%
data_dir = pathlib.Path('/content/drive/My Drive/Projecteye/CSC')

# %%
image_count = len(list(data_dir.glob('*/*.png')))
print("จำนวนรูปภาพทั้งหมด = ",image_count)
# Out:
# จำนวนรูปภาพทั้งหมด =  3202

# %%
image = cv2.imread("/content/drive/My Drive/Projecteye/CSC/CL8574 25-03-16 LE_000000.png")

# %%
x = 0
y = 496
h = 1200
w = 400

# %%
plt.title('Original Image')
plt.imshow(image)

# %%
cropped = image[x:w,y:h]
plt.title('Cropped Image')
plt.imshow(cropped)

# %%
os.chdir("/content/drive/My Drive/Projecteye")

# %%
for f in os.listdir():
  file_name, file_ext = os.path.splitext(f)
  if file_ext == '.png':
    with open('file_test.png','a') as ft:
      ft.write(file_name+'\n')
